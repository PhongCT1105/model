# %% [markdown]
# ### Case Study 4 :  Data Science Shark Tank
#
# ***Due Date: April 16, before 11:59pm***
#
# Note:
#
# ***part_1 and part_3 of Problem_1, and links to datasets (or API you are planning to use) should be sent to me by email (tghoshal@wpi.edu) before 11:59pm on April 1. You must CC all your group members in that email. Without this step, your project may not be approved for presentation on April 17.***
#
# also NOTE: There are always last minute issues submitting the case studies. DO NOT WAIT UNTIL THE LAST MINUTE!
#
#  ![Bilby Stampede](https://upload.wikimedia.org/wikipedia/en/6/68/Shark_Tank_Logo.jpg)

# %% [markdown]
# ### Introduction
#
# After the previous 3 case studies,  your are now equipped with three powerful skills of an effective data scientist: ***data gathering, model development, exploratory data analysis***. In this case study, your team is going to act like a data science team in a mid-size company. Your team will make use of these skills to come up with an idea for a new data science project, covince senior executives of the idea to get funding/ financial resources using data driven presentations, and finally build a prototype model for use by another team within the company.
#
# Your team needs to decide which business problem is important for the market your company is in (for example, social media market, housing market, search market, etc.). Then use data science approaches to gather data, explore the data, tie with business needs, make conjectures, develop models etc.
#
# The solution should include some key components of data science:
#
#     1) the business part to analyze the potential impact of your new/improved service, why the idea can make money, how are you planning to persuade senior executives (e.g. seniors VPS/ CEO/ COO) to allocate money for your project
#
#     2) collect data, perform exploratory data analysis, make conjectures in support of the business plan made in the previous step
#
#     3) Use one of your conjectures from step 2 as the motivation for developing a model. Use appropriate features from your data and build the model.
#
# NOTE, as opposed to the first three case studies, case study 4 is much much more open ended. A more complex model does not mean a better project. Also, strong exploratory data analysis loosely tied with the business question also does not mean a better project. Try to make all parts coherent so that they collectively tell one story.

# %% [markdown]
# # Background (Elevator Pitch)

# %%
# Should your project presentation be like this?

from IPython.display import YouTubeVideo
YouTubeVideo("7a_lu7ilpnI")

# %% [markdown]
# ## Some Resources
#
# ### Two videos on storytelling
#
# https://video.wpi.edu/Watch/g2T4NjBn
#
# https://video.wpi.edu/Watch/q2A6Dbg3
#
#
# **Optional Readings:**
#
#
# **APIs**
# * Zillow API: https://pypi.python.org/pypi/pyzillow
# * Google Map API: https://developers.google.com/api-client-library/python/apis/mapsengine/v1?hl=en
# * More APIs: https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition
#
# **Python libraries you may want to use:**
# * Scikit-learn (http://scikit-learn.org): machine learning tools in Python.
#
# **Data sources:**
# * UCI Machine Learning Repository: http://archive.ics.uci.edu/ml/
# * Statlib datasets: http://lib.stat.cmu.edu/datasets/
# * Kaggel: www.kaggle.com
# * Open Gov. Data: www.data.gov, www.data.gov.uk, https://www.data.gouv.fr/fr/, https://www.oecd.org/gov/digital-government/open-government-data.htm

# %% [markdown]
# ### Problem 1: the Business Part (20 points)
#  As a group, learn about the data science related business and research about the current markets: such as search, social media, advertisement, recommendation and so on. Pick one of the markets for further consideration, and propose a new data science project which you believe will be important for your company to do well in the market. Define precisely in the report and briefly in the cells below, what is the business problem that your team wants to solve.
# Why the problem is important to solve?
# Why you believe your team can make use of data science methodologies to solve the problem?
# How are you planing to persuade the senior executives to buy in your idea.

# %% [markdown]
# **Please describe here *briefly*  (please edit this cell)**
#
# 1) Your business problem to solve:
#
# Our business problem is “How do we predict prices for a newly manufactured car based on manufacturing year, manufacturers, features, and market price?”
#
# 2) Why the problem is important to solve?
#
# The problem is important because accurate pricing estimations could enable the company to offer competitive prices, thus attracting more customers. Also, by understanding the factors influencing the price, the company could optimize its pricing strategy.
#
# 3) What is your idea to solve the problem?
#
# Our idea to solve the problem is to analyze the dataset to identify relevant features that might influence car prices and make conjectures. Then we choose appropriate machine learning for price prediction tasks and evaluate the model.
#
# 4) What differences you could make with your data science approach?
#
# With our data science approach, we will conduct a thorough analysis of the dataset to identify all relevant features that could influence car prices. Then, we will find the best predictive models for price prediction tasks.
#
# 5) Why do you believe the idea deserves the financial resources of your company?
#
# Our idea deserves the financial resources since we could conduct a comprehensive analysis of the dataset to identify relevant features and create predictive models for car prices. This precision leads to more accurate price predictions, reducing the likelihood of underpricing or overpricing vehicles. Moreover, it can help the company stay ahead of competitors, impact the pricing strategies, and maximize profitability.

# %% [markdown]
# ### Problem 2: Data Gathering, Exploratory Data Analysis, Make Conjectures (20 points)
#
# Gather data in support of your responses for Problem 1. Use appropriate data analysis techniques to explore the data. Make conejectures in relation to problem 1. Find support for your conjectures using the data.

# %% [markdown]
# **Insert your answers in the cell below**
#
# **Add as many cells as needed**
#
#
# If you are using an API to collect data, provide the code below.
#
# If you collecting data from publicly available datasets, provide the links to them below.

# %% [markdown]
# https://www.kaggle.com/datasets/syedanwarafridi/vehicle-sales-data/data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings

# %%
# write here
# Import dataset

rawdf = pd.read_csv("Data.csv", low_memory=False)

rawdf.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
df = rawdf.dropna()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 472325 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          472325 non-null  int64
#  1   make          472325 non-null  object
#  2   model         472325 non-null  object
#  3   trim          472325 non-null  object
#  4   body          472325 non-null  object
#  5   transmission  472325 non-null  object
#  6   vin           472325 non-null  object
#  7   state         472325 non-null  object
#  8   condition     472325 non-null  float64
#  9   odometer      472325 non-null  float64
#  10  color         472325 non-null  object
#  11  interior      472325 non-null  object
#  12  seller        472325 non-null  object
#  13  mmr           472325 non-null  float64
#  14  sellingprice  472325 non-null  float64
#  15  saledate      472325 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 61.3+ MB

# %% [markdown]
# Conjecture 1: Numerical Factors to Selling Price

# %%
# Conjectures 1a: The value of the MMR and the selling price are positive correlated.

plt.figure(figsize=(8, 6))
plt.scatter(df["mmr"], df["sellingprice"], color='royalblue', alpha=0.5)
plt.xlabel("Manheim Market Report")
plt.ylabel("Selling Price")
plt.title("Manheim Market Report vs Selling Price")
plt.grid(True)
plt.show()

# %%
# Conjectures 1b: The more recent the model of the car, the greater its price tends to be.

# Create a figure and axes object
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Scatter plot for mmr
ax1.scatter(df["year"], df["mmr"], color='sandybrown', alpha=0.5)
ax1.set_xlabel("Manufacturing Year")
ax1.set_ylabel("Manheim Market Report")
ax1.set_title("Manufacutring Year vs Manheim Market Report")

colors = ['lightcoral' if s > m else 'palegreen' for s, m in zip(df["sellingprice"], df["mmr"])]

# Scatter plot for estimated price
ax2.scatter(df["year"], df["sellingprice"], color = colors, alpha=0.5)
ax2.set_xlabel("Manufacutring Year")
ax2.set_ylabel("Selling Price")
ax2.set_title("Manufacutring Year vs Selling Price")

# Set the same scale for both plots
min_x = min(df["year"])
max_x = max(df["year"])
min_y = min(min(df["sellingprice"]), min(df["mmr"]))
max_y = max(max(df["sellingprice"]), max(df["mmr"]))
ax1.set_xlim(min_x, max_x)
ax1.set_ylim(min_y, max_y)
ax2.set_xlim(min_x, max_x)
ax2.set_ylim(min_y, max_y)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
# Conjectures 1c: The better condition of the car, the greater its price tends to be.

# Create a figure and axes object
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Scatter plot for mmr
ax1.scatter(df["condition"], df["mmr"], color='olivedrab', alpha=0.2)
ax1.set_xlabel("Condition")
ax1.set_ylabel("Manheim Market Report")
ax1.set_title("Condition vs Manheim Market Report")

colors = ['lightcoral' if s > m else 'palegreen' for s, m in zip(df["sellingprice"], df["mmr"])]

# Scatter plot for estimated price
ax2.scatter(df["condition"], df["sellingprice"], color = colors, alpha=0.5)
ax2.set_xlabel("Condition")
ax2.set_ylabel("Selling Price")
ax2.set_title("Condition vs Selling Price")

# Set the same scale for both plots
min_x = min(df["condition"])
max_x = max(df["condition"])
min_y = min(min(df["sellingprice"]), min(df["mmr"]))
max_y = max(max(df["sellingprice"]), max(df["mmr"]))
ax1.set_xlim(min_x, max_x)
ax1.set_ylim(min_y, max_y)
ax2.set_xlim(min_x, max_x)
ax2.set_ylim(min_y, max_y)


# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
# Conjectures 1d: The lower odometer of the car, the greater its price tends to be.

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Scatter plot for mmr
ax1.scatter(df["odometer"], df["mmr"], color='turquoise', alpha=0.2)
ax1.set_xlabel("Odometer")
ax1.set_ylabel("Manheim Market Report")
ax1.set_title("Odometer vs Manheim Market Report")

colors = ['lightcoral' if s > m else 'palegreen' for s, m in zip(df["sellingprice"], df["mmr"])]

# Scatter plot for estimated price
ax2.scatter(df["odometer"], df["sellingprice"], color = colors, alpha=0.5)
ax2.set_xlabel("Odometer")
ax2.set_ylabel("Selling Price")
ax2.set_title("Odometer vs Selling Price")

# Set the same scale for both plots
min_x = min(df["odometer"])
max_x = max(df["odometer"])
min_y = min(min(df["sellingprice"]), min(df["mmr"]))
max_y = max(max(df["sellingprice"]), max(df["mmr"]))
ax1.set_xlim(min_x, max_x)
ax1.set_ylim(min_y, max_y)
ax2.set_xlim(min_x, max_x)
ax2.set_ylim(min_y, max_y)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
# Conjectures 1e: Year, odometer and mmr are the most important features that affect to sellingprice.

# Calculate correlation coefficients after dropping 'sellingprice' column
correlation_table = df.drop(columns=['sellingprice']).corr(method='pearson', numeric_only=True)

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_table, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5, center=0)
plt.title('Correlation Heatmap Numerical Column')
plt.xlabel('Column')
plt.ylabel('Column')
plt.show()

# %% [markdown]
# Conjecture 2: All categorial factors influence the Selling price

# %%
# Conjectures 2a: Ford, Chevrolet, Nissan are three biggest car manufactors.

# Compute frequency of each manufacturer
make_counts = df['make'].value_counts()

# Extract top 10 manufacturers
top_10_make = make_counts.head(10)

# Calculate count for "Others" category
other_count = make_counts.sum() - top_10_make.sum()

# Create a list of top 10 manufacturers and "Others"
all_make = list(top_10_make.index) + ['Others']
all_counts = list(top_10_make.values) + [other_count]

# Define colors for the top 10 manufacturers
colors = plt.cm.Blues(np.linspace(1, 0, len(all_make)))

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(all_counts, labels=all_make, autopct='%1.1f%%', colors=colors)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Car Manufacturers Distribution')
plt.show()

# %%
# Conjectures 2b: Base version is the most popular.

# Compute frequency of each additional designation
trim_counts = df['trim'].value_counts()

# Extract top 15 additional designations
top_15_trim = trim_counts.head(15)

# Calculate count for "Others" category
other_trim_count = trim_counts.sum() - top_15_trim.sum()

# Create a list of top 15 additional designations and "Others"
all_trim = list(top_15_trim.index) + ['Others']
all_trim_counts = list(top_15_trim.values) + [other_trim_count]

# Define colors for the top 15 manufacturers
colors = plt.cm.Purples(np.linspace(1, 0, len(all_trim)))

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(all_trim_counts, labels=all_trim, autopct='%1.1f%%', colors=colors)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Additional Designation Distribution')
plt.show()

# %%
# Conjectures 2c: Sedan and SUV are the most popular car body types.

# Compute frequency of each body type
body_counts = df['body'].value_counts()

# Extract top 10 body types
top_10_body = body_counts.head(10)

# Calculate count for "Others" category
other_body_count = body_counts.sum() - top_10_body.sum()

# Create a list of top 10 body types and "Others"
all_body = list(top_10_body.index) + ['Others']
all_body_counts = list(top_10_body.values) + [other_body_count]

# Define colors for the top 10 body types
colors = plt.cm.Greens(np.linspace(1, 0, len(all_body)))

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(all_body_counts, labels=all_body, autopct='%1.1f%%', colors=colors)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Body Types Distribution')
plt.show()

# %%
# Conjectures 2d: Florida, California, Texas are three most states have the most car sold.

# Compute frequency of each registered state
state_counts = df['state'].value_counts()

# Extract top 10 registered states
top_10_state = state_counts.head(10)

# Calculate count for "Others" category
other_state_count = state_counts.sum() - top_10_state.sum()

# Create a list of top 10 registered states and "Others"
all_state = list(top_10_state.index) + ['Others']
all_state_counts = list(top_10_state.values) + [other_state_count]

# Define colors for the top 10 registered states
colors = plt.cm.Oranges(np.linspace(0.8, 0.2, len(all_state)))

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(all_state_counts, labels=all_state, autopct='%1.1f%%', colors=colors)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Registered States Distribution')
plt.show()

# %%
# Conjectures 2e: Black, white and silver are the most popular colors.

# Remove rows with '-' in the 'color' column
df_cleaned = df[df['color'] != '—'].dropna()

# Compute frequency of each exterior color
color_counts = df_cleaned['color'].value_counts()

# Extract top 10 exterior colors
top_10_color = color_counts.head(10)

# Calculate count for "Others" category
other_color_count = color_counts.sum() - top_10_color.sum()

# Create a list of top 10 exterior colors and "Others"
all_color = list(top_10_color.index) + ['Others']
all_color_counts = list(top_10_color.values) + [other_color_count]

# Define colors for the top 10 exterior colors
colors = plt.cm.Reds(np.linspace(0.8, 0.2, len(all_color)))

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(all_color_counts, labels=all_color, autopct='%1.1f%%', colors=colors)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Exterior Colors Distribution')
plt.show()

# %%
# Conjectures 2f: Black is the most popular interior color.

# Remove rows with '-' in the 'interior' column
df_interior_cleaned = df[df['interior'] != '—'].dropna()

# Compute frequency of each interior color
interior_counts = df_interior_cleaned['interior'].value_counts()

# Extract top 5 interior colors
top_5_interior = interior_counts.head(5)

# Calculate count for "Others" category
other_interior_count = interior_counts.sum() - top_5_interior.sum()

# Create a list of top 5 interior colors and "Others"
all_interior = list(top_5_interior.index) + ['Others']
all_interior_counts = list(top_5_interior.values) + [other_interior_count]

# Define colors for the top 5 interior colors
colors = plt.cm.Greys(np.linspace(0.8, 0.2, len(all_state)))

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(all_interior_counts, labels=all_interior, autopct='%1.1f%%', colors=colors)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Interior Colors Distribution')
plt.show()

# %%
# Conjectures 2g: Nissan-infiniti it and ford motor credit company IIC are two most popular car seller

# Compute frequency of each seller
seller_counts = df['seller'].value_counts()

# Extract top 15 sellers
top_15_seller = seller_counts.head(15)

# Calculate count for "Others" category
other_seller_count = seller_counts.sum() - top_15_seller.sum()

# Create a list of top 15 sellers and "Others"
all_seller = list(top_15_seller.index) + ['Others']
all_seller_counts = list(top_15_seller.values) + [other_count]

# Define colors for the top 15 sellers
colors = plt.cm.YlGn(np.linspace(1, 0, len(all_seller)))

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(all_seller_counts, labels=all_seller, autopct='%1.1f%%', colors=colors)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Sellers Distribution')
plt.show()

# %%
# Conjectures 2h: Categorical value are less important features that affect to selling price.

from dython.nominal import associations

df_cat = df[['make', 'model', 'trim', 'body', 'transmission', 'state', 'color', 'interior', 'seller']]

cat_correlation = associations(df_cat, figsize=(10,10))

df_cat_corr = cat_correlation['corr']
df_cat_corr = df_cat_corr.dropna(axis=1, how='all').dropna(axis=0, how='all')
df_cat_corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# C:\Users\caoth\anaconda3\Lib\site-packages\dython\nominal.py:736: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   inf_nan.loc[columns[i], columns[j]] = _inf_nan_str(ij)
# C:\Users\caoth\anaconda3\Lib\site-packages\dython\nominal.py:737: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   inf_nan.loc[columns[j], columns[i]] = _inf_nan_str(ji)
# <style type="text/css">
# #T_ef02f_row0_col0, #T_ef02f_row1_col1, #T_ef02f_row2_col2, #T_ef02f_row3_col3, #T_ef02f_row4_col4, #T_ef02f_row5_col5, #T_ef02f_row6_col6, #T_ef02f_row7_col7, #T_ef02f_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ef02f_row0_col1, #T_ef02f_row1_col0 {
# ...

# %%
# Popular selling month
from datetime import datetime

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Given date string
date_string = "Tue Dec 16 2014 12:30:00 GMT-0800 (PST)"

# Remove the timezone abbreviation from the date string
date_string_without_timezone = date_string.split('(')[0].strip()

# Convert date string to datetime object
date_object = datetime.strptime(date_string_without_timezone, '%a %b %d %Y %H:%M:%S GMT%z')

# Count occurrences of each month
month_counts = {month: 0 for month in range(1, 13)}

# Extract month from the date object and count occurrences
month_counts[date_object.month] += 1

# Print the counts
#for month, count in month_counts.items():
#    print(f"{month}: {count}")

# %%
# Clean sale data

df_sales = rawdf

df_sales_cleaned = df_sales[df_sales['saledate'] != '—'].dropna() 
# print(df_sales_cleaned)

# List of months
months = range(1, 13)

# Count occurrences of each month
month_counts = {month: 0 for month in months}

# Iterate through each value in the 'date_column' and count occurrences of each month
for date_string in df_sales_cleaned['saledate']:
    date_string_without_timezone = date_string.split('(')[0].strip()
    date_object = datetime.strptime(date_string_without_timezone, '%a %b %d %Y %H:%M:%S GMT%z')
    month_counts[date_object.month] += 1

# Print the counts
# for month, count in month_counts.items():
#    print(f"Month {month}: {count} occurrences")
    
# print(month_counts)

# %%
# Convert the dictionary to a DataFrame
df_month_counts = pd.DataFrame(list(month_counts.items()), columns=['Month', 'Count'])

# Sort the DataFrame by month
df_month_counts = df_month_counts.sort_values(by='Month')

# print(df_month_counts)

# %%
# Conjectures 4: January is the best month to selling car and invest more in marketing

# Popular selling month

# Clean sale data
df_sales = rawdf
df_sales_cleaned = df_sales[df_sales['saledate'] != '—'].dropna() 

# List of months
months = range(1, 13)

# Count occurrences of each month
month_counts = {month: 0 for month in months}

# Iterate through each value in the 'date_column' and count occurrences of each month
for date_string in df_sales_cleaned['saledate']:
    date_string_without_timezone = date_string.split('(')[0].strip()
    date_object = datetime.strptime(date_string_without_timezone, '%a %b %d %Y %H:%M:%S GMT%z')
    month_counts[date_object.month] += 1

# Print the counts
# for month, count in month_counts.items():
#    print(f"Month {month}: {count} occurrences")
    
# Convert the dictionary to a DataFrame
df_month_counts = pd.DataFrame(list(month_counts.items()), columns=['Month', 'Count'])
df_month_counts = df_month_counts.sort_values(by='Month')

# Plotting the data
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

plt.plot(months, df_month_counts['Count'], color = "coral")
plt.title("Popular Sales Month")
plt.xlabel("Months")
plt.ylabel("Count")
plt.show()

# %%
# Conjectures 5: The most frequently purchased cars are those manufactured between 2012 and 2014.

# Sales per year

# Clean sale data
df_year = rawdf
df_year_cleaned = df_sales[df_sales['saledate'] != '—'].dropna() 

# Compute total sales per year
year_counts = df_year_cleaned['year'].value_counts()
top_10_year = year_counts.head(10) 
other_year_count = year_counts.sum() - top_10_year.sum()

# Create a list of each year
all_year = list(top_10_year.index) + ['Others']
all_year_counts = list(top_10_year.values) + [other_year_count]

# Define colors for the top 10 exterior colors
colors = plt.cm.Reds(np.linspace(0.8, 0.2, len(all_year)))

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(all_year_counts, labels=all_year, autopct='%1.1f%%', colors=colors)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Sales per year')
plt.show()

# %%
# Conjectures 6: 

# most popular interior and exterior
df = rawdf
df_interior = rawdf

# Remove rows with '-' in the 'color' column
df_color_cleaned = df_color[df_color['color'] != '—'].dropna()
df_interior_cleaned = df_interior[df_interior['interior'] != '—'].dropna()
 
df_color_interior_cleaned = df_color_cleaned.merge(df_interior_cleaned)
    
df_ci_count = df_color_interior_cleaned[['color', 'interior']].value_counts().reset_index(name='count') 
df_ci_count = df_ci_count.head(15)

# Plotting
exterior_colors = df_ci_count['color']
interior_colors = df_ci_count['interior']
counts = df_ci_count['count']

fig, ax = plt.subplots()

# Create a dictionary to keep track of added color labels
added_labels = {}

# Iterate through each color
for ext_color, int_color, count in zip(exterior_colors, interior_colors, counts):
    if int_color not in added_labels:
        ax.bar(ext_color, count, color=int_color, label=int_color)
        added_labels[int_color] = True
    else:
        ax.bar(ext_color, count, color=int_color)

ax.legend(title='Interior Color')
ax.set_xlabel('Exterior Color')
ax.set_ylabel('Count')
ax.set_title('Top 15 Exterior Color with Interior Color')

plt.show()

# %%
# Conjectures 7: 

# Best selling model + body 
import random


df_mb = rawdf

# Remove rows with '-' in the 'color' column
df_body_cleaned = df_mb[df_mb['body'] != '—'].dropna()
df_model_cleaned = df_mb[df_mb['model'] != '—'].dropna()
 
df_mb_cleaned = df_body_cleaned.merge(df_model_cleaned)
    
df_mb_count = df_mb_cleaned[['body', 'model']].value_counts().reset_index(name='count') 
df_mb_count = df_mb_count.head(15)

# Plotting
body = df_mb_count['body']
model = df_mb_count['model']
counts = df_mb_count['count']

fig, ax = plt.subplots()

def pick_color_function():
    """
    Generate a random color.
    """
    # Generate random values for RGB (Red, Green, Blue)
    r = random.random()
    g = random.random()
    b = random.random()

    # Return the color in RGB format
    return (r, g, b)

# Create a dictionary to map car models to colors
model_colors = {}

# Iterate through each car model and assign a unique color
for car_model in set(model):
    model_colors[car_model] = pick_color_function()  # You need to define how you want to assign colors here

# Iterate through each car body and car model
for car_body, car_model, count in zip(body, model, counts):
    ax.bar(car_body, count, color=model_colors[car_model], label=car_model)

ax.legend(title='Models')
ax.set_xlabel('Car body')
ax.set_ylabel('Count')
ax.set_title('Top 15 car model and body')

plt.show()

# %% [markdown]
# ### Problem 3: The Model Development Part  (20 points)
#
# **Insert your answers in the cell below**
#
# **Add as many cells as needed**
#
# Use one of the conjectures as the basis to create a model so that other teams in the company can use your model for new unseen data.

# %%
# Make data train from dataset
df_train_raw = rawdf
df_train_raw.head(5)
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
# Exploring features 

df_train_raw.nunique().to_dict()
# Out:
# {'year': 34,
#  'make': 96,
#  'model': 973,
#  'trim': 1963,
#  'body': 87,
#  'transmission': 4,
#  'vin': 550297,
#  'state': 64,
#  'condition': 41,
#  'odometer': 172278,
#  'color': 46,
#  'interior': 17,
#  'seller': 14263,
#  'mmr': 1101,
#  'sellingprice': 1887,
#  'saledate': 3766}

# %%
from sklearn.model_selection import train_test_split
# Feature engineering for all models

# Drop NaN value
data_train = df_train_raw.dropna()

# Make test
data_training, data_test = train_test_split(data_train, test_size=0.2, random_state=42)

print("Training dataset: ", data_training.shape)
print("Testing dataset", data_test.shape)
data_train.head(5)
# Out:
# Training dataset:  (377860, 16)
# Testing dataset (94465, 16)
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# ...

# %%
# Model 1: Leveraging various conjectures associated with selling prices enables us to predict the selling price of a car based on its features.

from sklearn.metrics import mean_squared_error, r2_score

# Drop unused features
data_train_1 = data_training.drop(columns=["vin", "saledate"])
data_test_1 = data_test.drop(columns=["vin", "saledate"])

print("Data training: ", data_train_1.shape)
print("Data testing: ", data_test_1.shape)

data_train_1.head(5)
# Out:
# Data training:  (377860, 14)
# Data testing:  (94465, 14)
#         year      make          model  trim           body transmission state  \
# 51686   2013     Lexus         RX 350  Base            SUV    automatic    tx
# 10090   2011  Infiniti  G Convertible   G37  G Convertible    automatic    fl
# 555324  2014    Nissan          Rogue    SV            suv    automatic    tx
# 189884  2012     Honda         Accord  EX-L          Sedan    automatic    pa
# 554447  2009   Hyundai        Elantra    SE          sedan    automatic    fl
#
#         condition  odometer   color interior  \
# 51686        49.0   46887.0    gray    black
# 10090        25.0   33309.0   black    black
# 555324       42.0   18701.0   white        —
# 189884       36.0   33574.0  silver     gray
# 554447       35.0   75696.0    gray     gray
#
#                                       seller      mmr  sellingprice
# 51686                            d&m leasing  32200.0       30200.0
# ...

# %%
# Extract features and targets from data train
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

X_train = data_train_1[data_train_1.columns[0:13]]
y_train = data_train_1[data_train_1.columns[13]]
X_test_final = data_train_1[data_train_1.columns[0:13]]
y_test_final = data_train_1[data_train_1.columns[13]]

# Preprocess data to deal with both numerical and categorical features
num_features = X_train.select_dtypes(include=['float64']).columns.tolist()
cat_features = X_train.select_dtypes(include=['object']).columns.tolist()
num_features_test = X_test_final.select_dtypes(include=['float64']).columns.tolist()
cat_features_test = X_test_final.select_dtypes(include=['object']).columns.tolist()

preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_features)
    ])

# Split dataset into train dataset and test dataset
X_train_30, X_test_30, y_train_30, y_test_30 = train_test_split(X_train, y_train, test_size=0.7, random_state=42)
X_train_50, X_test_50, y_train_50, y_test_50 = train_test_split(X_train, y_train, test_size=0.5, random_state=42)
X_train_70, X_test_70, y_train_70, y_test_70 = train_test_split(X_train, y_train, test_size=0.3, random_state=42)

print("30% data train: ", X_train_30.shape, y_train_30.shape)
print("30% data test : ", X_test_30.shape, y_test_30.shape)

print("50% data train: ", X_train_50.shape, y_train_50.shape)
print("50% data test : ", X_test_50.shape, y_test_50.shape)

print("70% data train: ", X_train_70.shape, y_train_70.shape)
print("70% data test : ", X_test_70.shape, y_test_70.shape)
# Out:
# 30% data train:  (113358, 13) (113358,)
# 30% data test :  (264502, 13) (264502,)
# 50% data train:  (188930, 13) (188930,)
# 50% data test :  (188930, 13) (188930,)
# 70% data train:  (264502, 13) (264502,)
# 70% data test :  (113358, 13) (113358,)

# %%
# Using random forest regressor model
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor

# Apply preprocessor and configurations to make the model work more efficency and faster
model_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42))
])

def randomForestRegressor(X_train, y_train, X_test, y_test):
    model_pipeline.fit(X_train, y_train)
    y_pred = model_pipeline.predict(X_test)
    print(f'Random Forest R^2 score: {r2_score(y_test, y_pred)}')
    plt.scatter(y_pred, y_test, color = "peachpuff", alpha=0.5)
    plt.show()

# model_pipeline.fit(X_train_30, y_train_30)

# y_pred = model_pipeline.predict(X_test_30)
# print(f'Random Forest R^2 score: {r2_score(y_test_30, y_pred)}')

# %%
# Using 30% dataset
randomForestRegressor(X_train_30, y_train_30, X_test_30, y_test_30)
# Out:
# Random Forest R^2 score: 0.972061345806958

# %%
# Using 50% dataset
randomForestRegressor(X_train_50, y_train_50, X_test_50, y_test_50)
# Out:
# Random Forest R^2 score: 0.9710564398946824

# %%
# Using 70% dataset
randomForestRegressor(X_train_70, y_train_70, X_test_70, y_test_70)
# Out:
# Random Forest R^2 score: 0.9745367078667203

# %%
# Final test

y_pred = model_pipeline.predict(X_test_final)
plt.scatter(y_pred, y_test_final, color="sandybrown", alpha=0.5)
plt.show()

print(f'Random Forest R^2 score: {r2_score(y_test_final, y_pred)}')
# Out:
# Random Forest R^2 score: 0.9772568458402271

# %%
# Model 2: Predict selling price by year, odometer, mmr
# => This one because year, odermeter, mmr have a high colleration

# importing modules and packages 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing 

data_train2 = data_training[["year", "odometer", "mmr", "sellingprice"]]
data_test2 = data_test[["year","odometer","mmr","sellingprice"]]

print("Data train: ", data_train2)
print("Data test : ", data_test2)
# Out:
# Data train:          year  odometer      mmr  sellingprice
# 51686   2013   46887.0  32200.0       30200.0
# 10090   2011   33309.0  24300.0       24000.0
# 555324  2014   18701.0  20200.0       18500.0
# 189884  2012   33574.0  15050.0       15100.0
# 554447  2009   75696.0   5250.0        6700.0
# ...      ...       ...      ...           ...
# 310022  2012   34183.0  12100.0       12400.0
# 433048  2006  133159.0   8400.0        7600.0
# 164717  2013   39710.0  20300.0       20000.0
# 181922  2006  163172.0   2475.0        2500.0
# 153201  2011   34011.0  22900.0       22000.0
#
# [377860 rows x 4 columns]
# Data test :          year  odometer      mmr  sellingprice
# 297590  2006  121222.0   4150.0        3500.0
# 90053   2010   42814.0  20400.0       19300.0
# 341051  2014   20032.0  22900.0       25000.0
# 362239  2013   52864.0  12050.0       10400.0
# 480321  2012   72306.0   8725.0        9400.0
# ...      ...       ...      ...           ...
# ...

# %%
# Extract features and targets

X_train = data_train2[["year", "odometer", "mmr"]]
y_train = data_train2[["sellingprice"]]

X_test_final = data_test2[["year", "odometer", "mmr"]]
y_test_final = data_test2[["sellingprice"]]

# %%
X_train_30, X_test_30, y_train_30, y_test_30 = train_test_split(X_train, y_train, test_size=0.7, random_state=42)
X_train_50, X_test_50, y_train_50, y_test_50 = train_test_split(X_train, y_train, test_size=0.5, random_state=42)
X_train_70, X_test_70, y_train_70, y_test_70 = train_test_split(X_train, y_train, test_size=0.3, random_state=42)

print("30% data train: ", X_train_30.shape, y_train_30.shape)
print("30% data test : ", X_test_30.shape, y_test_30.shape)

print("50% data train: ", X_train_50.shape, y_train_50.shape)
print("50% data test : ", X_test_50.shape, y_test_50.shape)

print("70% data train: ", X_train_70.shape, y_train_70.shape)
print("70% data test : ", X_test_70.shape, y_test_70.shape)
# Out:
# 30% data train:  (113358, 3) (113358, 1)
# 30% data test :  (264502, 3) (264502, 1)
# 50% data train:  (188930, 3) (188930, 1)
# 50% data test :  (188930, 3) (188930, 1)
# 70% data train:  (264502, 3) (264502, 1)
# 70% data test :  (113358, 3) (113358, 1)

# %%
# Using Multiple Linear Regression model with 30% dataset
model_30 = LinearRegression()
model_30.fit(X_train_30, y_train_30)
y_pred = model_30.predict(X_test_30)
print(f'Score: {r2_score(y_test_30, y_pred)}')
plt.scatter(y_pred, y_test_30, color="lightpink", alpha=0.5)
plt.show()
# Out:
# Score: 0.9657714914365501

# %%
# Using Multiple Linear Regression model with 50% dataset
model_50 = LinearRegression()
model_50.fit(X_train_50, y_train_50)
y_pred = model_50.predict(X_test_50)
print(f'Score: {r2_score(y_test_50, y_pred)}')
plt.scatter(y_pred, y_test_50, color="lightpink", alpha=0.5)
plt.show()
# Out:
# Score: 0.9641786342193437

# %%
# Using Multiple Linear Regression model with 70% dataset
model_70 = LinearRegression()
model_70.fit(X_train_70, y_train_70)
y_pred = model_70.predict(X_test_70)
print(f'Score: {r2_score(y_test_70, y_pred)}')
plt.scatter(y_pred, y_test_70, color="lightpink", alpha=0.5)
plt.show()
# Out:
# Score: 0.9676966401642308

# %%
# Final test

y_pred = model_70.predict(X_test_final)
plt.scatter(y_pred, y_test_final, color="darkorchid", alpha=0.5)
plt.show()

print(f'Linear Regression score: {r2_score(y_test_final, y_pred)}')
# Out:
# Linear Regression score: 0.9686613928409918

# %%
# Model 3: Predict selling price by categorical data

# Predict the price by categorical value
data_train = data_training[['make', 'model', 'trim', 'body', 'transmission', 'state', 'color', 'interior', 'seller', "sellingprice"]]
data_test_cat = data_test[['make', 'model', 'trim', 'body', 'transmission', 'state', 'color', 'interior', 'seller', "sellingprice"]]
# Out:
#             make          model             trim           body transmission  \
# 51686      Lexus         RX 350             Base            SUV    automatic
# 10090   Infiniti  G Convertible              G37  G Convertible    automatic
# 555324    Nissan          Rogue               SV            suv    automatic
# 189884     Honda         Accord             EX-L          Sedan    automatic
# 554447   Hyundai        Elantra               SE          sedan    automatic
# ...          ...            ...              ...            ...          ...
# 310022    Nissan         Altima            2.5 S          Sedan    automatic
# 433048     Lexus         IS 250             Base          Sedan    automatic
# 164717  Infiniti        G Sedan             G37x        G Sedan    automatic
# 181922      Ford         Fusion              SEL          Sedan    automatic
# 153201      Jeep       Wrangler  Unlimited Sport            SUV       manual
#
# ...

# %%
# Extract features and targets from data train
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

X_train = data_train[data_train.columns[0:9]]
y_train = data_train[data_train.columns[9]]
X_test_final = data_test_cat[data_test_cat.columns[0:9]]
y_test_final = data_test_cat[data_test_cat.columns[9]]

# Preprocess data to deal with both numerical and categorical features
num_features = X_train.select_dtypes(include=['float64']).columns.tolist()
cat_features = X_train.select_dtypes(include=['object']).columns.tolist()
num_features_test = X_test_final.select_dtypes(include=['float64']).columns.tolist()
cat_features_test = X_test_final.select_dtypes(include=['object']).columns.tolist()

preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_features)
    ])

# Split dataset into train dataset and test dataset
# X_train_30, X_test_30, y_train_30, y_test_30 = train_test_split(X_train, y_train, test_size=0.7, random_state=42)
# X_train_50, X_test_50, y_train_50, y_test_50 = train_test_split(X_train, y_train, test_size=0.5, random_state=42)
X_train_90, X_test_90, y_train_90, y_test_90 = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

# print("30% data train: ", X_train_30.shape, y_train_30.shape)
# print("30% data test : ", X_test_30.shape, y_test_30.shape)

# print("50% data train: ", X_train_50.shape, y_train_50.shape)
# print("50% data test : ", X_test_50.shape, y_test_50.shape)

print("90% data train: ", X_train_90.shape, y_train_90.shape)
print("90% data test : ", X_test_90.shape, y_test_90.shape)
# Out:
# 90% data train:  (340074, 9) (340074,)
# 90% data test :  (37786, 9) (37786,)

# %%
# Using random forest regressor model
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor

# Apply preprocessor and configurations to make the model work more efficency and faster
model_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42))
])

model_pipeline.fit(X_train_90, y_train_90)
y_pred = model_pipeline.predict(X_test_90)
print(f'Random Forest R^2 score: {r2_score(y_test_90, y_pred)}')
plt.scatter(y_pred, y_test_90, color = "lightseagreen", alpha = 0.2)
plt.show()
# Out:
# Random Forest R^2 score: 0.2984820448858492

# %% [markdown]
# ### Problem 4: Presentation in the class (10 mins and 10 points)
#
# * (5 points) Present your slides in the class.
# * (5 points) Participate in peer review process.
#
# Suggestion: You should practice so that your presentation does not exceed 12 minutes. All members of a group should share equal responsibility to present. **Points will be taken away if presentation exceeds 10 mins.**

# %% [markdown]
# # Report: communicate the results (20 points (or 25 points))
#
# ** minimum 8 pages **
#
# (1) (5 points) What is your business proposition?
#
# (2) (3 points) Why this topic is interesting or important to you? (Motivations)
#
# (3) (5 points) How did you analyse the data? What conjectures you made? Which conjecture you used as the basis of developing your model? Why?
#
# (4) (3 points) How does your analysis support your business proposition?
# (please include figures or tables in the report, but no source code)
#
# (5) (4 points) How does the model tie in with the business proposition?
#
# (5) (bonus 5 points) How did your team work together as a group from ideation to implementaion? Write in one page.

# %% [markdown]
# # Slides (for 10 minutes of presentation) (10 points)
#
#
# 1. (2 points) Motivation about the data collection, why the topic is interesting to you.
#
#
# 2. (3 points) Conjectures you made. Reasons behind choosing a particular conjecture for the basis of developing a model.
#
#
# 2. (3 points) Communicating Results (figure/table)
#
#
# 4. (2 points) Story telling (How all the parts (data, analysis, result) fit together as a story?)

# %% [markdown]
# # Done
#
# All set!
#
# **What do you need to submit?**
#
# * **Notebook File**: Save this IPython notebook, and find the notebook file in your folder (for example, "groupname.ipynb"). This is the file you need to submit. Please make sure all the plotted tables and figures are in the notebook.
#
# * **PPT Slides**
#
# * **Report**
#
# Put the Jupyter Notebook file, the report (in PDF) and PPT slides (converted to PDF) in a folder. Zip the folder. After zipping, it should have the extension .zip. The name of the .zip file should be casestudy_4_groupname.zip. Upload the .zip file on Canvas.
#
# **Note: Each team just needs to make one submission**
